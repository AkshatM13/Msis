# %%
import numpy
import pandas as pd

# %%
data=pd.read_csv("income_data.csv")
data
# Out:
#      Unnamed: 0    income  happiness
# 0             1  3.862647   2.314489
# 1             2  4.979381   3.433490
# 2             3  4.923957   4.599373
# 3             4  3.214372   2.791114
# 4             5  7.196409   5.596398
# ..          ...       ...        ...
# 493         494  5.249209   4.568705
# 494         495  3.471799   2.535002
# 495         496  6.087610   4.397451
# 496         497  3.440847   2.070664
# 497         498  4.530545   3.710193
#
# [498 rows x 3 columns]

# %%
df = data.drop('Unnamed: 0', axis=1)

# %%
X =df.iloc[:, :-1]
y = df["happiness"]
# Out:
#        income
# 0    3.862647
# 1    4.979381
# 2    4.923957
# 3    3.214372
# 4    7.196409
# ..        ...
# 493  5.249209
# 494  3.471799
# 495  6.087610
# 496  3.440847
# 497  4.530545
#
# [498 rows x 1 columns]

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=1/3.0, random_state=42)
y_test
# Out:
# 487    4.754168
# 73     4.159609
# 231    2.295700
# 175    2.311554
# 237    2.861274
#          ...
# 185    4.658743
# 26     3.565224
# 7      1.907137
# 451    4.216058
# 108    1.672391
# Name: happiness, Length: 166, dtype: float64

# %%
from sklearn.linear_model import LinearRegression
reg=LinearRegression()
reg.fit(X_train ,y_train)
# Out:
# LinearRegression()

# %%
y_pred=reg.predict(X_test)
y_pred
# Out:
# array([3.23056009, 2.2507678 , 3.21612545, 1.83153078, 1.78618823,
#        2.41961765, 4.43530839, 4.8405764 , 1.9298426 , 3.51190894,
#        4.09390297, 2.46047203, 2.87614142, 3.55172637, 2.80951251,
#        1.84866585, 2.5480731 , 5.14113112, 2.47917047, 3.99403102,
#        1.87529895, 2.75267487, 2.65600789, 1.285766  , 4.59652671,
#        1.77138987, 2.49205753, 5.34849458, 4.21202407, 4.12287827,
#        1.39543459, 3.72369544, 2.85605596, 3.71369323, 3.9983339 ,
#        4.00744675, 1.32297806, 2.50418925, 1.36926569, 2.28132809,
#        5.32662493, 4.41159302, 5.06524748, 4.81708662, 2.95973708,
#        2.18577673, 1.67096194, 3.18272149, 2.70096539, 1.51180211,
#        4.02610849, 3.00626377, 5.11529626, 3.71955426, 3.5941492 ,
#        3.35306747, 3.55451986, 3.94475272, 4.90966538, 3.82064055,
#        4.87790383, 1.60559674, 5.07183277, 2.3752856 , 2.2463635 ,
#        5.35994706, 4.70558059, 3.77133261, 2.43679373, 5.29768822,
#        4.5153279 , 3.43623748, 3.05911493, 3.08849277, 1.97919382,
#        3.14364817, 5.08881618, 5.35067789, 2.71650105, 4.24499049,
#        4.25519589, 1.65911247, 2.73077011, 3.936714  , 3.19442542,
#        1.77495349, 3.65006997, 4.26168427, 3.00211634, 2.08374022,
#        4.47428157, 3.56820944, 4.82193905, 5.13646033, 2.03374146,
#        4.45258257, 3.6620875 , 1.63244206, 3.6258782 , 4.65593125,
#        4.4988697 , 5.4022797 , 2.59857216, 4.55026786, 4.37433052,
#        2.2534352 , 4.92989904, 4.26389542, 4.96970926, 4.97771811,
#        1.55116722, 2.66008924, 4.72346738, 2.3931286 , 4.27393718,
#        2.63149561, 1.57221712, 4.79775808, 5.4472557 , 2.7836269 ,
#        3.71439848, 5.36381295, 2.29413049, 1.94109502, 2.12351053,
#        3.90703819, 1.53395915, 4.02452682, 1.90744583, 3.76100002,
#        2.60804871, 5.15236759, 1.63808159, 3.92911852, 1.91225667,
#        4.0977955 , 1.34494225, 5.06233412, 5.02394353, 2.65533257,
#        2.86906865, 5.27341471, 2.73247988, 1.68663674, 1.88511564,
#        1.33366034, 2.86525085, 2.61911092, 4.0225466 , 1.88855481,
#        3.61404415, 2.26822816, 2.4992014 , 3.27880592, 1.35237183,
#        5.15731667, 1.5145376 , 4.87694986, 3.83834048, 2.02695212,
#        1.54131186, 4.25681725, 2.98656364, 3.41116643, 3.86686174,
#        2.41625723])

# %%
plt
